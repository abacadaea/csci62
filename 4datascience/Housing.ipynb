# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_name = "Housing.csv"
df = pd.read_csv(file_name)

# %%
print(df)
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
len(df)
# Out:
# 545

# %%
df2 = df[:10] # first 10 rows of df, splicing
print(df2)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
print(len(df2))
# Out:
# 10

# %%
a=[1,2,3,4,5,6,7] #splicing
print(a)
print(a[3:6])
print(a[:4])
print(a[4:])
# Out:
# [1, 2, 3, 4, 5, 6, 7]
# [4, 5, 6]
# [1, 2, 3, 4]
# [5, 6, 7]

# %%
df3 = df[["price","area", "bedrooms", "bathrooms"]]
print(df3)
# Out:
#         price  area  bedrooms  bathrooms
# 0    13300000  7420         4          2
# 1    12250000  8960         4          4
# 2    12250000  9960         3          2
# 3    12215000  7500         4          2
# 4    11410000  7420         4          1
# ..        ...   ...       ...        ...
# 540   1820000  3000         2          1
# 541   1767150  2400         3          1
# 542   1750000  3620         2          1
# 543   1750000  2910         3          1
# 544   1750000  3850         3          1
#
# [545 rows x 4 columns]

# %%
print(df.columns)
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
plt.xlim(0,10000)
plt.ylim(0,6000000)
plt.scatter(df.area, df.price) # df.area is X, df.price is Y

# %%
print(df.area)
# Out:
# 0      7420
# 1      8960
# 2      9960
# 3      7500
# 4      7420
#        ...
# 540    3000
# 541    2400
# 542    3620
# 543    2910
# 544    3850
# Name: area, Length: 545, dtype: int64

# %%
print(df.price)
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
plt.scatter([1,2,3], [5,4,3])

# %%
df_ac = df[df.airconditioning == "yes"]
df_ac_4bd = df_ac[df_ac.bedrooms==4]
df_no_ac = df[df.airconditioning == "no"]

# %%
plt.scatter(df_ac.area, df_ac.price, label="AirConditioning")
plt.scatter(df_no_ac.area, df_no_ac.price, label="No AirConditioning")
plt.legend()
plt.title("Housing area vs. price")
# Out:
# Text(0.5, 1.0, 'Housing area vs. price')
